# %% [markdown]
# Write a function called your_vat. The function takes no parameter.
# The function asks the user to input the price of an item and VAT
# (vat should be a percentage). The function should return the price
# of the item plus VAT. If the price is 220 and, VAT is 15% your code
# should return a vat inclusive price of 253. Make sure that your code
# can handle ValueError. Ensure the code runs until valid numbers
# are entered. (hint: Your code should include a while loop).

# %%
def your_vat():
    while True:
        try:
            # Get and convert input
            price = float(input("Please enter price of item: "))
            vat = float(input("Please input associated VAT in %: "))

            # If both succeed, break the loop
            break

        except ValueError:
            print("Please enter valid numeric values for price and VAT.\n")

    # Calculate VAT-inclusive price
    total_price = price + (vat / 100 * price)
    return round(total_price, 2)  # Rounded to 2 decimal places

# %%
your_vat()
# Out:
# 525.0

# %%
def your_voucher():
    while True:

        try:
            user_input = float(input("Please enter your disired price"))
            user_vocher = float(input("pleaes enter your voucher amount"))


            break

        except ValueError:
            print("Please check you inputed values and try again")

    final_price = user_input - user_vocher
    print(f"Base on the voucher this your final price is {final_price}")

# %%
your_voucher()
# Out:
# Please check you inputed values and try again
# Please check you inputed values and try again
# Please check you inputed values and try again
# Base on the voucher this your final price is 150.0
