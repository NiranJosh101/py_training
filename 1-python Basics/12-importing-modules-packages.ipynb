# %% [markdown]
# # Importing Modules and Packages

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt,pi
print(sqrt(16))
print(sqrt(25))
print(pi)
# Out:
# 4.0
# 5.0
# 3.141592653589793

# %%
import numpy as np
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
# to import every function in a module
from math import *
sqrt(16)
# Out:
# 4.0

# %%
from package.maths import addition
addition(2,3)
# Out:
# 5

# %%
from package import maths
maths.addition(4,6)
# Out:
# 10

# %% [markdown]
# # Standard Library Overview

# %%
import array
arr=array.array('i', [1,2,3,4,5])
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
## random
import random
print(random.randint(1,10))
print(random.choice(['apple','banana','cherry']))
# Out:
# 2
# cherry

# %%
## File and directory access
import os
print(os.getcwd())
# Out:
# c:\Users\USER\Desktop\python-MLops\1-python Basics

# %%
os.mkdir('tested_dir')

# %%
## High level operations on files and collection of files
import shutil
shutil.copyfile('source.txt','destination.txt') # destination.txt file was created
# Out:
# 'destination.txt'

# %%
## Data Serialization
import json
data={'name': 'Josh', 'age':25}
json_str=json.dumps(data) # convert inputed data to str

print(json_str)
print(type(json_str))

parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Josh", "age": 25}
# <class 'str'>
# {'name': 'Josh', 'age': 25}
# <class 'dict'>

# %%
## csv
# create an example of a csv file

import csv

with open('example.csv', mode='w', newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['Josh',25])

with open('example.csv',mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Josh', '25']

# %%
## datatime
from datetime import datetime, timedelta

now=datetime.now()
print(now)

yesterday=now-timedelta(days=1)
print(yesterday)
# Out:
# 2025-05-06 18:51:04.421482
# 2025-05-05 18:51:04.421482

# %%
## time

import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1746582746.740582
# 1746582748.7413185

# %%
## Regular expression

import re

pattern='\d+'
text='There are 123 apples'
match=re.search(pattern,text)
print(match.group())
# Out:
# 123
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\USER\AppData\Local\Temp\ipykernel_11108\2273986034.py:5: SyntaxWarning: invalid escape sequence '\d'
#   pattern='\d+'
