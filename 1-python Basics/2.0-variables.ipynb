# %%
a=100
print(a)
# Out:
# 100

# %%
## Declaring and Assigning Variables

age = 25
height = 6.1
name = 'Josh'
is_student = True

print("age:", age)
print("Height:", height)
print("Name:", name)
# Out:
# age: 25
# Height: 6.1
# Name: Josh

# %% [markdown]
# # Data types

# %% [markdown]
# ### integers
