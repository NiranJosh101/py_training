# %% [markdown]
# # Python Operations

# %%
## Arithmethic Operation
a = 10
b = 5

add_result= a+b
sub_result= a-b
multi_result = a*b
div_result=a/b
floor_div_result=a//b # round up value
modulus_result=a%b
exponent_result=a**b
multi_results = a+b*a

print(add_result)
print(sub_result)
print(multi_result)
print(div_result)
print(floor_div_result)
print(modulus_result)
print(exponent_result)
print(multi_results)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000
# 60

# %%
c = 15
d = 4

c%d
# Out:
# 3

# %%
## Comparion Operators
## == Equal to
a=10
b=10

(a==b)
# Out:
# True

# %%
name1 = 'josh'
name2 = 'josh'

(name1 == name2)
# Out:
# True

# %%
## Not equal to
## !=
name2 != name1
# Out:
# False

# %% [markdown]
# ## Logical Operation

# %%
## And, Not, OR
X=True
Y=True

result= X and Y
print(result)
# Out:
# True

# %%
X=True
Y=False

result= X and Y
print(result)
# Out:
# False

# %%
## OR
X=True
Y=False

result= X or Y
print(result)
# Out:
# True

# %%
# Not (reverse anything)
X=True
not X
# Out:
# False
